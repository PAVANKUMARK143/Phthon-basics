# %% [markdown]
# <a href="https://colab.research.google.com/github/PAVANKUMARK143/Phthon-basics/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Age=int(input("Enter Your Age:"))

if Age>=18:
   print("You can vote🤝")

else:
    print("come Again Next year 🖐️")
# Out:
# Enter Your Age:12
# come Again Next year 🖐️

# %%
Marks = int(input("Enter Your Marks :"))

if Marks>=50:
   print("You passed 12th🤝")

else:
    print("Come Again Next year🖐️")
# Out:
# Enter Your Marks :45
# Come Again Next year🖐️
